# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
traces = '/home/melisa/Documents/neural_analysis/data/calcium_activity_day_wise/mouse_411857_session_1_trial_1_v1.4.20.3.0.1.1.0.npy'

# %%
calcium_traces = np.load(traces)

# %%
calcium_traces.shape
# Out:
# (72, 38204)

# %%
figure,ax = plt.subplots(1)
ax.plot(calcium_traces[50,:])
figure.set_size_inches([40, 5])

# %%
traces_old = '/home/melisa/Documents/neural_analysis/data/calcium_activity_day_wise/mouse_56165_session_1_trial_1_v1.4.20.3.0.1.1.0.npy'

# %%
calcium_traces_e = np.load(traces_old)

# %%
figure,ax = plt.subplots(1)
ax.plot(calcium_traces_e[30,:])
figure.set_size_inches([40, 5])
